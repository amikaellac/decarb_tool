# %%
import pandas as pdata
df=pd.read_csv('GPP_input.csv')
print(df.to_string())
# Out:
#     Ship names             Fuel Type  % Underway Annually  % Not Underway Annually  % Cold Iron Annually
# 0      LHA-6CL  F-76 Military Diesel                   40                       50                    10
# 1     LPD-17CL  F-76 Military Diesel                   40                       50                    10
# 2      CG-47CL  F-76 Military Diesel                   40                       50                    10
# 3      MCM-1CL  F-76 Military Diesel                   40                       50                    10
# 4     DDG-51CL  F-76 Military Diesel                   40                       50                    10
# 5     LSD-41CL  F-76 Military Diesel                   40                       50                    10
# 6      LHD-1CL  F-76 Military Diesel                   40                       50                    10
# 7      LCS-1CL  F-76 Military Diesel                   40                       50                    10
# ...

# %%
import pandas as pdata
df=pd.read_csv('GGP_Data.csv')
print(df.to_string())
# Out:
#     Ship names  Underway Fuel Consumption  Not Underway Fuel Consumption  Cold Iron Fuel Consumption BBL Fuel Consumed Underway (est) BBL Fuel Consumed Not Underway (est)  BBL Fuel Consumed Cold Iron (est) Total BBL Fuel Consumed (est) CO2E Underway (est Tons) CO2E Not underway (est Tons)  CO2E Cold Iron (est Tons) Total CO2E (est Tons)
# 0      LHA-6CL                    28.9920                         8.1288                      0.0153                       101,587.97                            35,604.14                              13.40                    137,205.51                47,872.31                    16,778.10                       6.32             64,656.73
# ...

# %%
list_of_ships = ['LHA-6CL', 'LPD-17CL', 'CG-47CL', 'MCM-1CL', 'DDG-51CL', 'LSD-41CL', 'LHD-1CL', 'LCS-1CL', 'LCC-19CL', 'FFG-7CL', 'LCS-2CL', 'LPD-4CL', 'DDG-1000CL', 'LHA-1CL', 'LSD-49CL']
for ship in list_of_ships:
  print(ship)
# Out:
# LHA-6CL
# LPD-17CL
# CG-47CL
# MCM-1CL
# DDG-51CL
# LSD-41CL
# LHD-1CL
# LCS-1CL
# LCC-19CL
# FFG-7CL
# LCS-2CL
# LPD-4CL
# DDG-1000CL
# LHA-1CL
# LSD-49CL

# %%
list_of_ships = ['LHA-6CL', 'LPD-17CL']
fuel_type = ['F-76 Military Diesel']
annual_hours_underway = ['3,504.00']
annual_hours_not_underway = ['4,380.00']
annual_hours_cold_iron = ['876.00']

for i in list_of_ships:
    for j in fuel_type:
        for k in annual_hours_underway:
            for l in annual_hours_not_underway:
                for m in annual_hours_cold_iron:
                    for n in bbl_fuel_consumed_underway:
                        print("class: ", i, "\nfuel type: ", j, "\nAnnual Hours Underway: ", k, "\nAnnual Hours Not Underway: ", l, "\nAnnual Hours Cold Iron: ", m, "\n")
# Out:
# class:  LHA-6CL
# fuel type:  F-76 Military Diesel
# Annual Hours Underway:  3,504.00
# Annual Hours Not Underway:  4,380.00
# Annual Hours Cold Iron:  876.00
#
# class:  LPD-17CL
# fuel type:  F-76 Military Diesel
# Annual Hours Underway:  3,504.00
# Annual Hours Not Underway:  4,380.00
# Annual Hours Cold Iron:  876.00

# %%
list_of_ships = ['LHA-6CL', 'LPD-17CL']
fuel_type = ['F-76 Military Diesel']
annual_hours_underway = ['3,504.00']
annual_hours_not_underway = ['4,380.00']
annual_hours_cold_iron = ['876.00']
bbl_fuel_consumed_underway = ['37,208.98']

for i in list_of_ships:
    for j in fuel_type:
        for k in annual_hours_underway:
            for l in annual_hours_not_underway:
                for m in annual_hours_cold_iron:
                    for n in bbl_fuel_consumed_underway:
                        print("class: ", i, "\nfuel type: ", j, "\nAnnual Hours Underway: ", k, "\nAnnual Hours Not Underway: ", l, "\nAnnual Hours Cold Iron: ", m, "\nBBl Fuel Consumed Underway: \n")
# Out:
# class:  LHA-6CL
# fuel type:  F-76 Military Diesel
# Annual Hours Underway:  3,504.00
# Annual Hours Not Underway:  4,380.00
# Annual Hours Cold Iron:  876.00
# BBl Fuel Consumed Underway:
#
# class:  LPD-17CL
# fuel type:  F-76 Military Diesel
# Annual Hours Underway:  3,504.00
# Annual Hours Not Underway:  4,380.00
# Annual Hours Cold Iron:  876.00
# BBl Fuel Consumed Underway:

# %%
list_of_ships = ['LHA-6CL', 'LPD-17CL']
fuel_type = ['F-76 Military Diesel']
annual_hours_underway = ['3,504.00']
annual_hours_not_underway = ['4,380.00']
annual_hours_cold_iron = ['876.00']
bbl_fuel_consumed_underway = [101,587.97, 50,590.75]

for i in list_of_ships:
    print("Class: ", i)
    print("Fuel Type: F-76 Military Diesel")
    print("Annual Hours Underway: 3,504.00")
    print("Annual Hours Not Underway: 4,380.00")
    print("Annual Hours Cold Iron: 876.00\n")
# Out:
# Class:  LHA-6CL
# Fuel Type: F-76 Military Diesel
# Annual Hours Underway: 3,504.00
# Annual Hours Not Underway: 4,380.00
# Annual Hours Cold Iron: 876.00
#
# Class:  LPD-17CL
# Fuel Type: F-76 Military Diesel
# Annual Hours Underway: 3,504.00
# Annual Hours Not Underway: 4,380.00
# Annual Hours Cold Iron: 876.00

# %%
list_of_ships = ['LHA-6CL', 'LPD-17CL']
fuel_type = ['F-76 Military Diesel', 'Methanol']
annual_hours_underway = ['3,504.00', '3,504.00']
annual_hours_not_underway = ['4,380.00', '4,380.00']
annual_hours_cold_iron = ['876.00', '876.00']
bbl_fuel_consumed_underway = ['101,587.97', '50,590.75']

for ships, fuel, ahu, ahnu, ahci, bfcu in zip(list_of_ships, fuel_type, annual_hours_underway, annual_hours_not_underway, annual_hours_cold_iron, bbl_fuel_consumed_underway):
    print(f"Class: {ships}, \nFuel: {fuel}, \nAnnual hours underway: {ahu}, \nAnnual hours not underway: {ahnu}, \nAnnual hours cold iron: {ahci}, \nBBL Fuel consumed underway: {bfcu}, \n")
# Out:
# Class: LHA-6CL,
# Fuel: F-76 Military Diesel,
# Annual hours underway: 3,504.00,
# Annual hours not underway: 4,380.00,
# Annual hours cold iron: 876.00,
# BBL Fuel consumed underway: 101,587.97,
#
# Class: LPD-17CL,
# Fuel: Methanol,
# Annual hours underway: 3,504.00,
# Annual hours not underway: 4,380.00,
# Annual hours cold iron: 876.00,
# BBL Fuel consumed underway: 50,590.75,

# %%
list_of_ships = ['LHA-6CL', 'LPD-17CL', 'CG-47CL', 'MCM-1CL', 'DDG-51CL', 'LSD-41CL', 'LHD-1CL', 'LCS-1CL', 'LCC-19CL', 'FFG-7CL', 'LCS-2CL', 'LPD-4CL', 'DDG-1000CL', 'LHA-1CL', 'LSD-49CL' ]
fuel_type = ['F-76 Military Diesel', 'F-76 Military Diesel', 'F-76 Military Diesel', 'F-76 Military Diesel', 'F-76 Military Diesel', 'F-76 Military Diesel', 'F-76 Military Diesel', 'F-76 Military Diesel', 'F-76 Military Diesel', 'F-76 Military Diesel', 'F-76 Military Diesel', 'F-76 Military Diesel', 'F-76 Military Diesel', 'F-76 Military Diesel', 'F-76 Military Diesel']
annual_hours_underway = ['3,504.00', '3,504.00', '3,504.00', '3,504.00', '3,504.00', '3,504.00', '3,504.00', '3,504.00', '3,504.00', '3,504.00', '3,504.00', '3,504.00', '3,504.00', '3,504.00', '3,504.00']
annual_hours_not_underway = ['4,380.00', '4,380.00', '4,380.00', '4,380.00', '4,380.00', '4,380.00', '4,380.00','4,380.00', '4,380.00', '4,380.00', '4,380.00', '4,380.00', '4,380.00', '4,380.00', '4,380.00']
annual_hours_cold_iron = ['876.00', '876.00', '876.00', '876.00', '876.00', '876.00', '876.00', '876.00', '876.00', '876.00', '876.00', '876.00', '876.00', '876.00', '876.00']
bbl_fuel_consumed_underway = ['101,587.97', '50,590.75', '104,632.94', '3,878.23', '87,133.97', '42,615.65', '149,589.26', '37,208.98', '80,725.15', '37,247.52', '34,675.23', '75,567.26', '98,374.80', '162,939.50', '42,293.28']
bbl_fuel_consumed_not_underway = ['35,604.14', '20,544.83', '26,638.28', '1,142.30', '23,673.46', '16,492.45', '58,416.06', '2,876.78', '51,863.58', '7,832.32', '7,897.58', '40,119.49', '20,570.23', '82,825.80', '15,317.74']
bbl_fuel_consumed_cold_iron = ['13.40', '60.18', '14.72', '1.05', '12.61', '16.99', '106.96', '25.93', '19.18', '26.28', '45.11', '36.79', '0.44', '161.62', '26.98']
total_bbl_fuel_consumed = ['137,205.51', '71,195.76', '131,285.94', '5,021.58', '110,820.04', '59,125.09', '208,112.28', '40,111.69', '132,607.92', '45,106.12', '42,617.93', '115,723.54', '118,945.47', '245,926.93', '57,638.00']
c02e_underway_est = ['47,872.31', '23,840.39', '49,307.23', '1,827.58', '41,061.01', '20,082.20', '70,492.44', '17,534.36', '38,040.92', '17,552.52', '16,340.36', '35,610.32', '46,358.14', '76,783.61', '19,930.29']
c02e_not_underway_est = ['16,778.10', '9,681.54', '12,553.02', '538.30', '11,155.88', '7,771.90', '27,527.98', '1,355.66', '24,440.19', '3,690.90', '3,721.65', '18,905.91', '9,693.52', '39,030.83', '7,218.33']
c02e_cold_iron_est = ['6.32', '28.36', '6.94', '0.50', '5.94', '8.01', '50.40', '12.22', '9.04', '12.38', '21.26', '17.34', '0.21', '76.16', '12.71']
total_c02e_est = ['64,656.73', '33,550.29', '61,867.19', '2,366.37', '52,222.84', '27,862.11', '98,070.83', '18,902.23', '62,490.15', '21,255.81', '20,083.27', '54,533.56', '56,051.86', '115,890.60', '27,161.33']


for ships, fuel, ahu, ahnu, ahci, bfcu, bfcnu, bfcci, tbfc, cue, cnue, ccie, tce in zip(list_of_ships, fuel_type, annual_hours_underway, annual_hours_not_underway, annual_hours_cold_iron, bbl_fuel_consumed_underway, bbl_fuel_consumed_not_underway, bbl_fuel_consumed_cold_iron, total_bbl_fuel_consumed, c02e_underway_est, c02e_not_underway_est, c02e_cold_iron_est, total_c02e_est):
    print(f"Class: {ships} \nFuel: {fuel} \nAnnual hours underway: {ahu} \nAnnual hours not underway: {ahnu} \nAnnual hours cold iron: {ahci} \nBBL Fuel consumed underway: {bfcu} \nBBL fuel consumed not underway: {bfcnu} \nBBL Fuel Consumed Cold Iron (est): {bfcci}  \nTOTAL BBL FUEL CONSUMED: {tbfc} \n\nCO2E Underway (est Tons): {cue} \nCO2E Not underway (est Tons): {cnue} \nCO2E Cold Iron (est Tons): {ccie} \nTOTAL CO2E (est Tons): {tce} \\n\n")
# Out:
# Class: LHA-6CL
# Fuel: F-76 Military Diesel
# Annual hours underway: 3,504.00
# Annual hours not underway: 4,380.00
# Annual hours cold iron: 876.00
# BBL Fuel consumed underway: 101,587.97
# BBL fuel consumed not underway: 35,604.14
# BBL Fuel Consumed Cold Iron (est): 13.40
# TOTAL BBL FUEL CONSUMED: 137,205.51
#
# CO2E Underway (est Tons): 47,872.31
# CO2E Not underway (est Tons): 16,778.10
# CO2E Cold Iron (est Tons): 6.32
# TOTAL CO2E (est Tons): 64,656.73
#
#
# Class: LPD-17CL
# Fuel: F-76 Military Diesel
# Annual hours underway: 3,504.00
# Annual hours not underway: 4,380.00
# Annual hours cold iron: 876.00
# BBL Fuel consumed underway: 50,590.75
# BBL fuel consumed not underway: 20,544.83
# BBL Fuel Consumed Cold Iron (est): 60.18
# TOTAL BBL FUEL CONSUMED: 71,195.76
#
# CO2E Underway (est Tons): 23,840.39
# CO2E Not underway (est Tons): 9,681.54
# CO2E Cold Iron (est Tons): 28.36
# TOTAL CO2E (est Tons): 33,550.29
#
#
# Class: CG-47CL
# Fuel: F-76 Military Diesel
# ...

# %%
list_of_ships = ['LHA-6CL', 'LPD-17CL', 'CG-47CL', 'MCM-1CL', 'DDG-51CL', 'LSD-41CL', 'LHD-1CL', 'LCS-1CL', 'LCC-19CL', 'FFG-7CL', 'LCS-2CL', 'LPD-4CL', 'DDG-1000CL', 'LHA-1CL', 'LSD-49CL' ]
fuel_type = ['F-76 Military Diesel']
annual_hours_underway = ['3,504.00']
annual_hours_not_underway = ['4,380.00']
annual_hours_cold_iron = ['876.00']
bbl_fuel_consumed_underway = ['101,587.97', '50,590.75', '104,632.94', '3,878.23', '87,133.97', '42,615.65', '149,589.26', '37,208.98', '80,725.15', '37,247.52', '34,675.23', '75,567.26', '98,374.80', '162,939.50', '42,293.28']
bbl_fuel_consumed_not_underway = ['35,604.14', '20,544.83', '26,638.28', '1,142.30', '23,673.46', '16,492.45', '58,416.06', '2,876.78', '51,863.58', '7,832.32', '7,897.58', '40,119.49', '20,570.23', '82,825.80', '15,317.74']
bbl_fuel_consumed_cold_iron = ['13.40', '60.18', '14.72', '1.05', '12.61', '16.99', '106.96', '25.93', '19.18', '26.28', '45.11', '36.79', '0.44', '161.62', '26.98']
total_bbl_fuel_consumed = ['137,205.51', '71,195.76', '131,285.94', '5,021.58', '110,820.04', '59,125.09', '208,112.28', '40,111.69', '132,607.92', '45,106.12', '42,617.93', '115,723.54', '118,945.47', '245,926.93', '57,638.00']

c02e_underway_est = ['47,872.31', '23,840.39', '49,307.23', '1,827.58', '41,061.01', '20,082.20', '70,492.44', '17,534.36', '38,040.92', '17,552.52', '16,340.36', '35,610.32', '46,358.14', '76,783.61', '19,930.29']
c02e_not_underway_est = ['16,778.10', '9,681.54', '12,553.02', '538.30', '11,155.88', '7,771.90', '27,527.98', '1,355.66', '24,440.19', '3,690.90', '3,721.65', '18,905.91', '9,693.52', '39,030.83', '7,218.33']
c02e_cold_iron_est = ['6.32', '28.36', '6.94', '0.50', '5.94', '8.01', '50.40', '12.22', '9.04', '12.38', '21.26', '17.34', '0.21', '76.16', '12.71']
total_c02e_est = ['64,656.73', '33,550.29', '61,867.19', '2,366.37', '52,222.84', '27,862.11', '98,070.83', '18,902.23', '62,490.15', '21,255.81', '20,083.27', '54,533.56', '56,051.86', '115,890.60', '27,161.33']

ship = input("Enter the ship: ")

if ship in ship_list:
    index = ship_list.index(ship)
    print(f"Class: {ship}")
    print(f"Fuel: {fuel_type[0]}")
    print(f"Annual hours underway: {annual_hours_underway[0]}")
    print(f"Annual hours not underway: {annual_hours_not_underway[0]}")
    print(f"Annual hours cold iron: {annual_hours_cold_iron[0]}")
    print(f"BBL Fuel consumed underway: {bbl_fuel_consumed_underway[index]}")
    print(f"BBL fuel consumed not underway: {bbl_fuel_consumed_not_underway[index]}")
    print(f"BBL fuel consumed cold iron (est): {bbl_fuel_consumed_cold_iron[index]}")
    print(f"TOTAL BBL FUEL CONSUMED: {total_bbl_fuel_consumed[index]} \n\n")
    print(f"CO2E Underway (est Tons): {c02e_underway_est[index]}")
    print(f"CO2E Not underway (est Tons):  {c02e_not_underway_est[index]}")
    print(f"CO2E Cold Iron (est Tons):  {c02e_cold_iron_est[index]}")
    print(f"TOTAL CO2E (est Tons): {total_c02e_est[index]}")
    
else:
    print("Ship not found in the list.")
# Out:
# Enter the ship:  LHA-6CL
# Class: LHA-6CL
# Fuel: F-76 Military Diesel
# Annual hours underway: 3,504.00
# Annual hours not underway: 4,380.00
# Annual hours cold iron: 876.00
# BBL Fuel consumed underway: 101,587.97
# BBL fuel consumed not underway: 35,604.14
# BBL fuel consumed cold iron (est): 13.40
# TOTAL BBL FUEL CONSUMED: 137,205.51
#
#
# CO2E Underway (est Tons): 47,872.31
# CO2E Not underway (est Tons):  16,778.10
# CO2E Cold Iron (est Tons):  6.32
# TOTAL CO2E (est Tons): 64,656.73

# %%
ship_list = ['LHA-6CL', 'LPD-17CL', 'CG-47CL', 'MCM-1CL', 'DDG-51CL', 'LSD-41CL', 'LHD-1CL', 'LCS-1CL', 'LCC-19CL', 'FFG-7CL', 'LCS-2CL', 'LPD-4CL', 'DDG-1000CL', 'LHA-1CL', 'LSD-49CL' ]
fuel_type_list = ['F-76 Military Diesel', 'Ethanol', 'LPG', 'Methanol']
annual_hours_underway = ['7,008.00']
annual_hours_not_underway = ['4,380.00']
annual_hours_cold_iron = ['876.00']

#calculations for military diesel
diesel_bbl_fuel_consumed_underway = ['203,175.94', '101,181.50', '209,265.89', '7,756.45', '174,267.94', '85,231.30', '299,178.53', '74,417.95', '161,450.30', '74,495.04', '69,350.47', '151,134.53', '196,749.60', '325,879.01', '84,586.56']
diesel_bbl_fuel_consumed_not_underway = ['28,483.32', '16,435.86', '21,310.63', '913.84', '18,938.77', '13,193.96', '46,732.85', '2,301.43', '41,490.86', '6,265.85', '6,318.06', '32,095.59', '16,456.19', '66,260.64', '12,254.19']
diesel_bbl_fuel_consumed_cold_iron = ['13.40', '60.18', '14.72', '1.05', '12.61', '16.99', '106.96', '25.93', '19.18', '26.28', '45.11', '36.79', '0.44', '161.62', '26.98']
diesel_total_bbl_fuel_consumed = ['231,672.65', '117,677.55', '230,591.23', '8,671.35', '193,219.32', '98,442.25', '346,018.34', '76,745.31', '202,960.35', '80,787.17', '75,713.64', '183,266.91', '213,206.22', '392,301.27', '96,867.73']
diesel_c02e_underway_est = ['95,744.63', '47,680.77', '98,614.46', '3,655.15', '82,122.02', '40,164.40', '140,984.89', '35,068.72', '76,081.84', '35,105.04', '32,680.71', '71,220.63', '92,716.28', '153,567.22', '39,860.57']
diesel_c02e_not_underway_est = ['13,422.48', '7,745.24', '10,042.42', '430.64', '8,924.71', '6,217.52', '22,022.39', '1,084.52', '19,552.15', '2,952.72', '2,977.32', '15,124.73', '7,754.81', '31,224.66', '5,774.66']
diesel_c02e_cold_iron_est = ['6.32', '28.36', '6.94', '0.50', '5.94', '8.01', '50.40', '12.22', '9.04', '12.38', '21.26', '17.34', '0.21', '76.16', '12.71']
diesel_total_c02e_est = ['109,173.42', '55,454.37', '108,663.81', '4,086.29', '91,052.67', '46,389.93', '163,057.68', '36,165.468', '95,643.04', '38,070.15', '35,679.30', '86,362.70', '100,471.30', '184,868.05', '45,647.95']

#calculations for Ethanol
ethanol_bbl_fuel_consumed_underway = ['342,389.08', '170,509.57', '352,651.77',  '13,071.06', '293,673.74', ' 143,630.52 ', '504,171.22 ', '125,408.03', '272,073.66', '125,537.94', '116,868.38', '254,689.67', '331,559.51', '549,166.48', '142,544.02']
ethanol_bbl_fuel_consumed_not_underway = ['47,999.66', '27,697.47 ', '35,912.35', '1,540.00', '31,915.33', '22,234.27', '78,753.50', '3,878.33', '69,919.79', '10,559.12', '10,647.11', '54,087.01', '27,731.72', '111,661.45', '20,650.58']
ethanol_bbl_fuel_consumed_cold_iron = [' 22.59 ', ' 101.42 ', ' 24.80 ', ' 1.77 ', ' 21.26 ', ' 28.64 ', ' 180.25 ', ' 43.70 ', ' 32.33 ', ' 44.29 ', ' 76.03 ', ' 62.00 ', ' 0.74 ', ' 272.36 ', ' 45.47 ']
ethanol_total_bbl_fuel_consumed = [' 390,411.32 ', ' 198,308.46 ', ' 388,588.93 ', ' 14,612.83 ', ' 325,610.34 ', ' 165,893.42 ', ' 583,104.97 ', ' 129,330.06 ', ' 342,025.78 ', ' 136,141.35 ', ' 127,591.51 ', ' 308,838.68 ', ' 359,291.97 ', ' 661,100.29 ', ' 163,240.06 ']
ethanol_c02e_underway_est = [' 91,146.67 ', ' 45,390.99 ', ' 93,878.68 ', ' 3,479.62 ', ' 78,178.26 ', ' 38,235.57 ', ' 134,214.34 ', ' 33,384.60 ', ' 72,428.15 ', ' 33,419.19 ', ' 31,111.28 ', ' 67,800.39 ', ' 88,263.75 ', ' 146,192.44 ', ' 37,946.34 ']
ethanol_c02e_not_underway_est = [' 12,777.89 ', ' 7,373.28 ', ' 9,560.15 ', ' 409.96 ', ' 8,496.11 ', ' 5,918.94 ', ' 20,964.80 ', ' 1,032.44 ', ' 18,613.20 ', ' 2,810.92 ', ' 2,834.34 ', ' 14,398.39 ', ' 7,382.40 ', ' 29,725.16 ', ' 5,497.35 ']
ethanol_c02e_cold_iron_est = [' 6.01 ', ' 27.00 ', ' 6.60 ', ' 0.47 ', ' 5.66 ', ' 7.62 ', ' 47.98 ', ' 11.63 ', ' 8.61 ', ' 11.79 ', ' 20.24 ', ' 16.51 ', ' 0.20 ', ' 72.51 ', ' 12.10 ']
ethanol_total_c02e_est = [' 103,930.57 ', ' 52,791.27 ', ' 103,445.43 ', ' 3,890.05 ', ' 86,680.03 ', ' 44,162.13 ', ' 155,227.13 ', ' 34,428.68 ', ' 91,049.95 ', ' 36,241.90 ', ' 33,965.86 ', ' 82,215.29 ', ' 95,646.35 ', ' 175,990.10 ', ' 43,455.79 ']

#calculations for LPG
lpg_bbl_fuel_consumed_underway = [' 192,593.86 ', ' 95,911.63 ', ' 198,366.62 ', ' 7,352.47 ', ' 165,191.48 ', ' 80,792.17 ', ' 283,596.31 ', ' 70,542.02 ', ' 153,041.43 ', ' 70,615.09 ', ' 65,738.46 ', ' 143,262.94 ', ' 186,502.23 ', ' 308,906.14 ', ' 80,181.01 ']
lpg_bbl_fuel_consumed_not_underway = [' 26,999.81  ', ' 15,579.83 ', ' 20,200.70 ', ' 866.25 ', ' 17,952.38 ', ' 12,506.78 ', ' 44,298.85 ', ' 2,181.56 ', ' 39,329.88 ', ' 5,939.51 ', ' 5,989.00 ', ' 30,423.94 ', ' 15,599.09 ', ' 62,809.57 ', ' 11,615.95 ']
lpg_bbl_fuel_consumed_cold_iron = [' 12.70 ', ' 57.05 ', ' 13.95 ', ' 1.00 ', '  11.96  ', ' 16.11 ', ' 101.39 ', ' 24.58 ', ' 18.19 ', ' 24.91 ', ' 42.76 ', ' 34.88 ', ' 0.42 ', ' 153.20 ', ' 25.58 ']
lpg_total_bbl_fuel_consumed = [' 219,606.37 ', ' 111,548.51 ', ' 218,581.27 ', ' 8,219.72 ', ' 183,155.81 ', ' 93,315.05 ', ' 327,996.55 ', ' 72,748.16 ', ' 192,389.50 ', ' 76,579.51 ', ' 71,770.22 ', ' 173,721.76 ', ' 202,101.73 ', ' 371,868.91 ', ' 91,822.54 ']
lpg_c02e_underway_est = [' 50,645.84 ', ' 25,221.60 ', ' 52,163.89 ', ' 1,933.46 ', ' 43,439.92 ', ' 21,245.68 ', ' 74,576.49 ', ' 18,550.23 ', ' 40,244.86 ', ' 18,569.44 ', ' 17,287.05 ', ' 37,673.44 ', ' 49,043.94 ', ' 81,232.14 ', ' 21,084.97 ']
lpg_c02e_not_underway_est = [' 7,100.06 ', ' 4,096.98 ', ' 5,312.12 ', ' 227.79 ', ' 4,720.88 ', ' 3,288.87 ', ' 11,649.14 ', ' 573.68 ', ' 10,342.46 ', ' 1,561.89 ', ' 1,574.91 ', ' 8,000.50 ', ' 4,102.05 ', ' 16,516.85 ', ' 3,054.61 ']
lpg_c02e_cold_iron_est = [' 3.34 ', ' 15.00 ', ' 3.67 ', ' 0.26 ', ' 3.14 ', ' 4.24 ', ' 26.66 ', ' 6.46 ', ' 4.78 ', ' 6.55 ', ' 11.25 ', ' 9.17 ', ' 0.11 ', ' 40.29 ', ' 6.73 ']
lpg_total_c02e_est = [' 57,749.24 ', ' 29,333.58 ', ' 57,479.68 ', ' 2,161.51 ', ' 48,163.95 ', ' 24,538.79 ', ' 86,252.29 ', ' 19,130.37 ', ' 50,592.10 ', ' 20,137.89 ', ' 18,873.21 ', ' 45,683.10 ', ' 53,146.10 ', ' 97,789.28 ', ' 24,146.30 ']

#calculations for Methanol
methanol_bbl_fuel_consumed_underway = ['  407,246.92  ', ' 202,808.74 ', ' 419,453.65 ', ' 15,547.08 ', ' 349,303.57 ', ' 170,838.06 ', ' 599,675.02 ', ' 149,163.74 ', ' 323,611.84 ', ' 149,318.25 ', ' 139,006.44 ', ' 302,934.85 ', ' 394,365.94 ', ' 653,193.61 ', ' 169,545.75 ']
methanol_bbl_fuel_consumed_not_underway = [' 57,092.11 ', ' 32,944.13 ', ' 42,715.13 ', ' 1,831.71 ', ' 37,960.97 ', ' 26,446.05 ', ' 93,671.57 ', ' 4,612.99 ', ' 83,164.51 ', ' 12,559.31 ', ' 12,663.96 ', ' 64,332.57 ', ' 32,984.87 ', ' 132,813.18 ', ' 24,562.36 ']
methanol_bbl_fuel_consumed_cold_iron = [' 26.86 ', ' 120.63 ', ' 29.50 ', ' 2.11 ', ' 25.28 ', ' 34.06 ', ' 214.39 ', ' 51.97 ', ' 38.45 ', ' 52.68 ', ' 90.43 ', ' 73.75 ', ' 0.88 ', ' 323.96 ', ' 54.08 ']
methanol_total_bbl_fuel_consumed = [' 464,365.89 ', ' 235,873.50 ', ' 462,198.28 ', ' 17,380.90 ', ' 387,289.83 ', ' 197,318.17 ', ' 693,560.98 ', ' 153,828.70 ', ' 406,814.80 ', ' 161,930.24 ', ' 151,760.83 ', ' 367,341.16 ', ' 427,351.68 ', ' 786,330.74 ', ' 194,162.19 ']
methanol_c02e_underway_est = [ '107,092.53', ' 53,332.02 ', ' 110,302.50 ', ' 4,088.37 ', ' 91,855.34 ', ' 44,924.78 ', ' 157,694.79 ', ' 39,225.15 ', ' 85,099.26 ', ' 39,265.78 ', ' 36,554.12 ', ' 79,661.89 ', ' 103,705.26 ', ' 171,768.41 ', ' 44,584.95 ']
methanol_c02e_not_underway_est = [' 15,013.34 ', ' 8,663.22 ', ' 11,232.67 ', ' 481.68 ', ' 9,982.49 ', ' 6,954.44 ', ' 24,632.54 ', ' 1,213.07 ', ' 21,869.53 ', ' 3,302.68 ', ' 3,330.20 ', ' 16,917.35 ', ' 8,673.93 ', ' 34,925.49 ', ' 6,459.09 ']
methanol_c02e_cold_iron_est = [' 7.06 ', ' 31.72 ', ' 7.76 ', ' 0.55 ', ' 6.65 ', ' 8.96 ', ' 56.38 ', ' 13.67 ', ' 10.11 ', ' 13.85 ', ' 23.78 ', ' 19.39 ', ' 0.23 ', ' 85.19 ', ' 14.22 ']
methanol_total_c02e_est = [' 122,112.94 ', ' 62,026.96 ', ' 121,542.93 ', ' 4,570.60 ', ' 101,844.47 ', ' 51,888.18 ', ' 182,383.70 ', ' 40,451.88 ', ' 106,978.90 ', ' 42,582.32 ', ' 39,908.10 ', ' 96,598.63 ', ' 112,379.42 ', ' 206,779.09 ', ' 51,058.26 ']

#ship_list = ['LHA-6CL', 'LPD-17CL', 'CG-47CL', 'MCM-1CL', 'DDG-51CL', 'LSD-41CL', 'LHD-1CL', 'LCS-1CL', 'LCC-19CL', 'FFG-7CL', 'LCS-2CL', 'LPD-4CL', 'DDG-1000CL', 'LHA-1CL', 'LSD-49CL']
#fuel_type_list = ['F-76 Military Diesel', 'Ethanol', 'LPG', 'Methanol']

ship = input("Enter the ship: ")
fuel_type = input("Enter the fuel type:")
print("\n\n")

if ship in ship_list and fuel_type in fuel_type_list:
    index = ship_list.index(ship)
    fuel_index = fuel_type_list.index(fuel_type)

    print(f"Class: {ship}")
    print(f"Fuel: {fuel_type}")
    print(f"Annual hours underway: {annual_hours_underway[0]}")
    print(f"Annual hours not underway: {annual_hours_not_underway[0]}")
    print(f"Annual hours cold iron: {annual_hours_cold_iron[0]}")

    if fuel_type == 'F-76 Military Diesel':
        print(f"BBL Fuel consumed underway: {diesel_bbl_fuel_consumed_underway[index]}")
        print(f"BBL fuel consumed not underway: {diesel_bbl_fuel_consumed_not_underway[index]}")
        print(f"BBL fuel consumed cold iron (est): {diesel_bbl_fuel_consumed_cold_iron[index]}")
        print(f"TOTAL BBL FUEL CONSUMED: {diesel_total_bbl_fuel_consumed[index]}\n")
        print(f"CO2E Underway (est Tons): {diesel_c02e_underway_est[index]}")
        print(f"CO2E Not Underway (est Tons): {diesel_c02e_not_underway_est[index]}")
        print(f"CO2E Cold Iron (est Tons): {diesel_c02e_cold_iron_est[index]}")
        print(f"TOTAL CO2E (est Tons): {diesel_total_c02e_est[index]}\n\n")

    elif fuel_type == 'Ethanol':
        print(f"BBL Fuel consumed underway: {ethanol_bbl_fuel_consumed_underway[index]}")
        print(f"BBL fuel consumed not underway: {ethanol_bbl_fuel_consumed_not_underway[index]}")
        print(f"BBL fuel consumed cold iron (est): {ethanol_bbl_fuel_consumed_cold_iron[index]}")
        print(f"TOTAL BBL FUEL CONSUMED: {ethanol_total_bbl_fuel_consumed[index]}\n")
        print(f"CO2E Underway (est Tons): {ethanol_c02e_underway_est[index]}")
        print(f"CO2E Not Underway (est Tons): {ethanol_c02e_not_underway_est[index]}")
        print(f"CO2E Cold Iron (est Tons): {ethanol_c02e_cold_iron_est[index]}")
        print(f"TOTAL CO2E (est Tons): {ethanol_total_c02e_est[index]}\n\n")

    elif fuel_type == 'LPG':
        print(f"BBL Fuel consumed underway: {lpg_bbl_fuel_consumed_underway[index]}")
        print(f"BBL fuel consumed not underway: {lpg_bbl_fuel_consumed_not_underway[index]}")
        print(f"BBL fuel consumed cold iron (est): {lpg_bbl_fuel_consumed_cold_iron[index]}")
        print(f"TOTAL BBL FUEL CONSUMED: {lpg_total_bbl_fuel_consumed[index]}\n")
        print(f"CO2E Underway (est Tons): {lpg_c02e_underway_est[index]}")
        print(f"CO2E Not Underway (est Tons): {lpg_c02e_not_underway_est[index]}")
        print(f"CO2E Cold Iron (est Tons): {lpg_c02e_cold_iron_est[index]}")
        print(f"TOTAL CO2E (est Tons): {lpg_total_c02e_est[index]}\n\n")

    elif fuel_type == 'Methanol':
        print(f"BBL Fuel consumed underway: {methanol_bbl_fuel_consumed_underway[index]}")
        print(f"BBL fuel consumed not underway: {methanol_bbl_fuel_consumed_not_underway[index]}")
        print(f"BBL fuel consumed cold iron (est): {methanol_bbl_fuel_consumed_cold_iron[index]}")
        print(f"TOTAL BBL FUEL CONSUMED: {methanol_total_bbl_fuel_consumed[index]}\n")
        print(f"CO2E Underway (est Tons): {methanol_c02e_underway_est[index]}")
        print(f"CO2E Not Underway (est Tons): {methanol_c02e_not_underway_est[index]}")
        print(f"CO2E Cold Iron (est Tons): {methanol_c02e_cold_iron_est[index]}")
        print(f"TOTAL CO2E (est Tons): {methanol_total_c02e_est[index]}\n\n")

else:
    print("Invalid ship or fuel type. Please try again.")
# Out:
# Enter the ship: LSD-41CL
# Enter the fuel type:LPG
#
#
#
# Class: LSD-41CL
# Fuel: LPG
# Annual hours underway: 7,008.00
# Annual hours not underway: 4,380.00
# Annual hours cold iron: 876.00
# BBL Fuel consumed underway:  80,792.17
# BBL fuel consumed not underway:  12,506.78
# BBL fuel consumed cold iron (est):  16.11
# TOTAL BBL FUEL CONSUMED:  93,315.05
#
# CO2E Underway (est Tons):  21,245.68
# CO2E Not Underway (est Tons):  3,288.87
# CO2E Cold Iron (est Tons):  4.24
# TOTAL CO2E (est Tons):  24,538.79
