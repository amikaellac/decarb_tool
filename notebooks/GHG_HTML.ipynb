# %%
from IPython.display import display, HTML

html_table = """
<style>
table {
  border-collapse: collapse;
  width: 100%;
}

th, td {
  border: 1px solid black;
  padding: 8px;
  text-align: left;
}

th {
  background-color: #f2f2f2;
}

tr:nth-child(even) {
  background-color: #f9f9f9;
}

</style>

<h1> GHG Model</h1>
<h3> LHA-6CL </h3>
<table>
  <tr>
    <th style="text-align: left;"></th>
    <th style="text-align: left;"> MILITARY DIESEL</th>
    <th style="text-align: left;"> ETHANOL   </th>
    <th style="text-align: left;"> LIQUIFIED PETROLEUM GAS   </th>
    <th style="text-align: left;"> METHANOL </th>
  </tr>
  <tr>
    <td style="text-align: left;">BBL Fuel Consumed Underway (est)</td>
    <td style="text-align: left;">203,175.94</td>
    <td style="text-align: left;"> 342,389.08  </td>
    <td style="text-align: left;"> 192,593.86 </td>
    <td style="text-align: left;"> 407,246.92 </td>
  </tr>
  <tr>
    <td style="text-align: left;">BBL Fuel Consumed Not Underway (est)</td>
    <td style="text-align: left;">28,483.32</td>
    <td style="text-align: left;"> 47,999.66 </td>
    <td style="text-align: left;">  26,999.81  </td>
    <td style="text-align: left;">  57,092.11  </td>
  </tr>
 <tr>
    <td style="text-align: left;">BBL Fuel Consumed Cold Iron (est)</td>
    <td style="text-align: left;"> 13.40</td>
    <td style="text-align: left;">  22.59  </td>
    <td style="text-align: left;">   12.70   </td>
    <td style="text-align: left;">   26.86   </td>
  </tr>
    <tr>
    <td style="text-align: left;"><b>Total BBL Fuel Consumed (est)</b></td>
    <td style="text-align: left;"> 231,672.65</td>
    <td style="text-align: left;">   390,411.32   </td>
    <td style="text-align: left;">    219,606.37    </td>
    <td style="text-align: left;">    464,365.89    </td>
    </tr>
 </tr>
    <tr>
    <td style="text-align: left;"> </td>
    <td style="text-align: left;"> </td>
    <td style="text-align: left;"> </td>
    <td style="text-align: left;"> </td>
    <td style="text-align: left;"> </td>
    </tr>
 </tr>
    <tr>
    <td style="text-align: left;">CO2E Underway (est Tons)</td>
    <td style="text-align: left;"> 95,744.63 </td>
    <td style="text-align: left;">  91,146.67 </td>
    <td style="text-align: left;">  50,645.84 </td>
    <td style="text-align: left;">  107,092.53 </td>
    </tr>
<tr>
    <td style="text-align: left;">CO2E Not underway (est Tons)</td>
    <td style="text-align: left;"> 13,422.48 </td>
    <td style="text-align: left;">   12,777.89  </td>
    <td style="text-align: left;">   7,100.06  </td>
    <td style="text-align: left;">   15,013.34  </td>
    </tr>
<tr>
    <td style="text-align: left;">CO2E Cold Iron (est Tons)</td>
    <td style="text-align: left;"> 6.32 </td>
    <td style="text-align: left;">    6.01   </td>
    <td style="text-align: left;">    3.34   </td>
    <td style="text-align: left;">    7.06   </td>
    </tr>
<tr>
    <td style="text-align: left;"><b>Total CO2E (est Tons)</b></td>
    <td style="text-align: left;"> 109,173.42 </td>
    <td style="text-align: left;"> 103,930.57 </td>
    <td style="text-align: left;"> 57,749.24  </td>
    <td style="text-align: left;"> 122,112.94  </td>
    </tr>
</table>

<h3> LPD-17CL </h3>
<table>
  <tr>
    <th style="text-align: left;"></th>
    <th style="text-align: left;"> MILITARY DIESEL</th>
    <th style="text-align: left;"> ETHANOL   </th>
    <th style="text-align: left;"> LIQUIFIED PETROLEUM GAS   </th>
    <th style="text-align: left;"> METHANOL </th>
  </tr>
  <tr>
    <td style="text-align: left;">BBL Fuel Consumed Underway (est)</td>
    <td style="text-align: left;"> 101,181.50 </td>
    <td style="text-align: left;"> 170,509.57 </td>
    <td style="text-align: left;">  95,911.63  </td>
    <td style="text-align: left;">  202,808.74  </td>
  </tr>
  <tr>
    <td style="text-align: left;">BBL Fuel Consumed Not Underway (est)</td>
    <td style="text-align: left;"> 16,435.86 </td>
    <td style="text-align: left;">  27,697.47  </td>
    <td style="text-align: left;">   15,579.83   </td>
    <td style="text-align: left;">   32,944.13   </td>
  </tr>
 <tr>
    <td style="text-align: left;">BBL Fuel Consumed Cold Iron (est)</td>
    <td style="text-align: left;"> 60.18 </td>
    <td style="text-align: left;">   101.42   </td>
    <td style="text-align: left;">    57.05    </td>
    <td style="text-align: left;">    120.63    </td>
  </tr>
    <tr>
    <td style="text-align: left;"><b>Total BBL Fuel Consumed (est)</b></td>
    <td style="text-align: left;"> 117,677.55</td>
    <td style="text-align: left;">   198,308.46    </td>
    <td style="text-align: left;">     111,548.51     </td>
    <td style="text-align: left;">     235,873.50     </td>
    </tr>
 </tr>
    <tr>
    <td style="text-align: left;"> </td>
    <td style="text-align: left;"> </td>
    <td style="text-align: left;"> </td>
    <td style="text-align: left;"> </td>
    <td style="text-align: left;"> </td>
    </tr>
 </tr>
    <tr>
    <td style="text-align: left;">CO2E Underway (est Tons)</td>
    <td style="text-align: left;"> 47,680.77 </td>
    <td style="text-align: left;">   45,390.99  </td>
    <td style="text-align: left;">   25,221.60  </td>
    <td style="text-align: left;">   53,332.02  </td>
    </tr>
<tr>
    <td style="text-align: left;">CO2E Not underway (est Tons)</td>
    <td style="text-align: left;"> 7,745.24 </td>
    <td style="text-align: left;">   7,373.28   </td>
    <td style="text-align: left;">    4,096.98   </td>
    <td style="text-align: left;">    8,663.22   </td>
    </tr>
<tr>
    <td style="text-align: left;">CO2E Cold Iron (est Tons)</td>
    <td style="text-align: left;"> 28.36 </td>
    <td style="text-align: left;">  27.00   </td>
    <td style="text-align: left;">   15.00   </td>
    <td style="text-align: left;">   31.72   </td>
    </tr>
<tr>
    <td style="text-align: left;"><b>Total CO2E (est Tons)</b></td>
    <td style="text-align: left;"> 55,454.37 </td>
    <td style="text-align: left;">  52,791.27  </td>
    <td style="text-align: left;">  29,333.58   </td>
    <td style="text-align: left;">  62,026.96   </td>
    </tr>
</table>



"""

display(HTML(html_table))
# Out:
# <style>
# table {
#   border-collapse: collapse;
#   width: 100%;
# }
#
# th, td {
#   border: 1px solid black;
#   padding: 8px;
#   text-align: left;
# }
#
# th {
#   background-color: #f2f2f2;
# }
#
# tr:nth-child(even) {
#   background-color: #f9f9f9;
# }
#
# </style>
#
# <h1> GHG Model</h1>
# <h3> LHA-6CL </h3>
# <table>
#   <tr>
#     <th style="text-align: left;"></th>
#     <th style="text-align: left;"> MILITARY DIESEL</th>
#     <th style="text-align: left;"> ETHANOL   </th>
#     <th style="text-align: left;"> LIQUIFIED PETROLEUM GAS   </th>
#     <th style="text-align: left;"> METHANOL </th>
#   </tr>
#   <tr>
#     <td style="text-align: left;">BBL Fuel Consumed Underway (est)</td>
#     <td style="text-align: left;">203,175.94</td>
#     <td style="text-align: left;"> 342,389.08  </td>
#     <td style="text-align: left;"> 192,593.86 </td>
#     <td style="text-align: left;"> 407,246.92 </td>
#   </tr>
#   <tr>
# ...
